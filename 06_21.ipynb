# %% [markdown]
# <a href="https://colab.research.google.com/github/Tonge-Shim/Bladder/blob/main/06_21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.programmersought.com/article/64794725120/
#
# https://brainder.org/2012/09/23/the-nifti-file-format/?blogsub=confirming#subscribe-blog

# %%
import os
import numpy as np
import nibabel as nib
import skimage.io as io

# %%
img = nib.load('/content/t2sag_subj0001.nii.gz')
img_arr=img.get_fdata()
img_arr=np.squeeze(img_arr)
img_arr.shape
# Out:
# (1024, 1024, 24)

# %%
import matplotlib
from matplotlib import pylab as plt
import nibabel as nib
from nibabel import nifti1
from nibabel.viewers import OrthoSlicer3D

# %%
img_path="/content/t2sag_subj0001.nii.gz"
img=nib.load(img_path)
print(img.shape)
print(img.header['db_name'])

#Some pictures may be four-dimensional
width,height,queue=img.dataobj.shape
OrthoSlicer3D(img.dataobj).show()
# Out:
# (1024, 1024, 24)
# b''

# %%
num=1
for i in range(0,queue):
    img_arr=img.dataobj[:,:,i]
    plt.subplot(3, 8,num)
    plt.imshow(img_arr,cmap='gray')
    num+=1
plt.show()

# %%
img_pathlabel="/content/label_t2sag_subj0001.nii.gz"
imglabel=nib.load(img_pathlabel)
num=1
for i in range(0,queue):
    img_arrlabel=imglabel.dataobj[:,:,i]
    plt.subplot(3, 8,num)
    plt.imshow(img_arrlabel,cmap='gray')
    num+=1
plt.show()
